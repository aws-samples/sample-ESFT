# %% [markdown]
# # Expert Specialized Fine-Tuning on SageMaker - ESFT on SageMaker

# %% [markdown]
# ---
#
# This notebook's CI test result for us-east-1 is as follows. CI test results in other regions can be found at the end of the notebook.
#
# ![](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-east-1/build_and_train_models)
#
# ---

# %% [markdown]
# ## Introduction
#
# This notebook demonstrates **Expert Specialized Fine-Tuning (ESFT)** on Amazon SageMaker, a novel approach for efficiently fine-tuning sparse architectural Large Language Models (LLMs) such as Mixture of Experts (MoE) models.
#
# ### Background
#
# ESFT is based on the research paper ["Let the Expert Stick to His Last: Expert-Specialized Fine-Tuning for Sparse Architectural Large Language Models"](https://arxiv.org/abs/2407.01906) by DeepSeek. This method addresses the challenge of fine-tuning MoE models by selectively training only the most relevant experts for specific tasks, rather than updating all parameters.
#
# ### Key Benefits of ESFT:
#
# - **Efficiency**: Reduces computational overhead by training only relevant experts
# - **Performance**: Maintains or improves model performance on target tasks
# - **Scalability**: Enables fine-tuning of large MoE models with limited resources
# - **Task Specialization**: Allows experts to specialize in specific domains or tasks
#
# ### Example Use Case
#
# In this notebook, we demonstrate ESFT using:
# - **Model**: Qwen3-30B (a 30B parameter MoE model)
# - **Task**: Low-resource translation (Cherokee → English)
# - **Dataset**: Cherokee-English translation pairs for specialized language translation
#
# This example showcases how ESFT can be particularly effective for low-resource language tasks where traditional fine-tuning might be challenging due to limited data availability.

# %% [markdown]
# ## Contents
#
# This notebook covers the following steps for running ESFT on SageMaker:
#
# 1. **Setup and Configuration** - Configure training parameters and environment
# 2. **Import Required Libraries** - Load necessary SageMaker and AWS libraries
# 3. **AWS Setup** - Configure AWS credentials and execution roles
# 4. **Upload Dataset to S3** - Prepare Cherokee-English translation dataset
# 5. **Configure Hyperparameters** - Set ESFT-specific training parameters
# 6. **Configure SageMaker Training Components** - Set up compute resources and storage
# 7. **Create and Configure ModelTrainer** - Initialize the SageMaker training job
# 8. **Start Training Job** - Launch the ESFT training process
# 9. **Training Results** - Monitor and retrieve training outputs
#
# ### Prerequisites
#
# - AWS account with SageMaker access
# - Pre-built ESFT Docker container in ECR
# - Cherokee-English translation dataset
# - Appropriate IAM roles and permissions

# %% [markdown]
# ## 1. Setup and Configuration
#
# First, let's set up the configuration parameters for ESFT training. We'll use the Qwen3-30B model for Cherokee to English translation as our example use case.

# %%
# Configuration parameters for ESFT training
INSTANCE = "ml.p4d.24xlarge"
NUM_GPU = 8
SCORE_TOKENS = 16384
TRAIN_DATASET = "datasets/train/translation.jsonl"
EVAL_DATASET = "datasets/eval/translation.jsonl"
MAX_RUN_HOURS = 5
STORAGE_VOLUME = 100

# Pre-built SageMaker container with ESFT implementation
# Region should be fixed to us-east-1 if you use the pre-built image below. 
# Because the image can't be used cross by region
REGION = "us-east-1"
SM_IMAGE_URI = "798050803670.dkr.ecr.us-east-1.amazonaws.com/esft-sagemaker-nvcr:0.0.1"

# Model and ESFT-specific parameters
MODEL = "Qwen/Qwen3-30B-A3B-Instruct-2507"  # Using Qwen3-30B for Cherokee-English translation
SCORE_FUNCTION = "token"
SCORE_THRESHOLD = 0.2
WORLD_SIZE = 1

print(f"Instance Type: {INSTANCE}")
print(f"Number of GPUs: {NUM_GPU}")
print(f"Model: {MODEL}")
print(f"Training Dataset: {TRAIN_DATASET}")
print(f"Validation Dataset: {EVAL_DATASET}")
print(f"SageMaker Image: {SM_IMAGE_URI}")
print(f"\nESFT Configuration:")
print(f"Score Function: {SCORE_FUNCTION}")
print(f"Score Threshold: {SCORE_THRESHOLD}")
print(f"Score Tokens: {SCORE_TOKENS}")
# Out:
# Instance Type: ml.p4d.24xlarge
# Number of GPUs: 8
# Model: Qwen/Qwen3-30B-A3B-Instruct-2507
# Training Dataset: datasets/train/translation.jsonl
# Validation Dataset: datasets/eval/translation.jsonl
# SageMaker Image: 798050803670.dkr.ecr.us-east-1.amazonaws.com/esft-sagemaker-nvcr:0.0.1
#
# ESFT Configuration:
# Score Function: token
# Score Threshold: 0.2
# Score Tokens: 16384

# %% [markdown]
# ## 2. Import Required Libraries
#
# Import the necessary libraries for SageMaker training.

# %%
# !pip install sagemaker==3.4.0 boto3

import os
import json
import boto3
boto3.setup_default_session(region_name=REGION)

from sagemaker.train import ModelTrainer
from sagemaker.train.configs import (
    SourceCode, 
    InputData, 
    Compute,
    StoppingCondition,
    TensorBoardOutputConfig,
)
from sagemaker.core.helper.session_helper import get_execution_role
import time
from utils import s3_upload
# Out:
# Requirement already satisfied: sagemaker==3.4.0 in ./.venv/venv/lib/python3.12/site-packages (3.4.0)
# Requirement already satisfied: boto3 in ./.venv/venv/lib/python3.12/site-packages (1.42.40)
# Requirement already satisfied: botocore[crt] in ./.venv/venv/lib/python3.12/site-packages (1.42.40)
# Requirement already satisfied: sagemaker-core<3.0.0,>=2.4.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker==3.4.0) (2.4.0)
# Requirement already satisfied: sagemaker-train<2.0.0,>=1.4.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker==3.4.0) (1.4.0)
# Requirement already satisfied: sagemaker-serve<2.0.0,>=1.4.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker==3.4.0) (1.4.0)
# Requirement already satisfied: sagemaker-mlops<2.0.0,>=1.4.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker==3.4.0) (1.4.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./.venv/venv/lib/python3.12/site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in ./.venv/venv/lib/python3.12/site-packages (from boto3) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./.venv/venv/lib/python3.12/site-packages (from botocore[crt]) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in ./.venv/venv/lib/python3.12/site-packages (from botocore[crt]) (2.6.3)
# Requirement already satisfied: awscrt==0.29.2 in ./.venv/venv/lib/python3.12/site-packages (from botocore[crt]) (0.29.2)
# Requirement already satisfied: six>=1.5 in ./.venv/venv/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore[crt]) (1.17.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2.12.5)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (6.0.3)
# Requirement already satisfied: jsonschema<5.0.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (4.26.0)
# Requirement already satisfied: platformdirs<5.0.0,>=4.0.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (4.5.1)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (13.9.4)
# Requirement already satisfied: mock<5.0,>4.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (4.0.3)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (6.11.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (4.15.0)
# Requirement already satisfied: pytz>=2021.1 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2025.2)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2.32.5)
# Requirement already satisfied: attrs>=20.3.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (25.4.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (24.2)
# Requirement already satisfied: protobuf<7.0.0,>=3.12 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (6.31.1)
# Requirement already satisfied: pandas>=1.0.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2.3.3)
# Requirement already satisfied: numpy>=1.9.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2.4.2)
# Requirement already satisfied: smdebug_rulesconfig>=1.0.1 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (1.0.1)
# Requirement already satisfied: schema>=0.7.5 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (0.7.8)
# Requirement already satisfied: omegaconf>=2.1.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2.3.0)
# Requirement already satisfied: torch>=1.9.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2.10.0)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (1.17.0)
# Requirement already satisfied: cloudpickle>=2.0.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (3.1.2)
# Requirement already satisfied: paramiko>=2.11.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (4.0.0)
# Requirement already satisfied: tblib>=1.7.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (3.2.2)
# Requirement already satisfied: deepdiff in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (8.6.1)
# Requirement already satisfied: mlflow in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.9.0)
# Requirement already satisfied: sagemaker_schema_inference_artifacts in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.0.5)
# Requirement already satisfied: pytest in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (9.0.2)
# Requirement already satisfied: tqdm in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (4.67.2)
# Requirement already satisfied: psutil in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (7.2.2)
# Requirement already satisfied: tritonclient[http] in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (2.64.0)
# Requirement already satisfied: onnx in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.20.1)
# Requirement already satisfied: onnxruntime in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.23.2)
# Requirement already satisfied: graphene<4,>=3 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-train<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.4.3)
# Requirement already satisfied: jinja2<4.0,>=3.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-train<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.1.6)
# Requirement already satisfied: sagemaker-mlflow<1.0.0,>=0.0.1 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-train<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.2.0)
# Requirement already satisfied: nest_asyncio>=1.5.0 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker-train<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.6.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in ./.venv/venv/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker-train<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in ./.venv/venv/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker-train<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in ./.venv/venv/lib/python3.12/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/venv/lib/python3.12/site-packages (from jinja2<4.0,>=3.0->sagemaker-train<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/venv/lib/python3.12/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/venv/lib/python3.12/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/venv/lib/python3.12/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (0.30.0)
# Requirement already satisfied: mlflow-skinny==3.9.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.9.0)
# Requirement already satisfied: mlflow-tracing==3.9.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.9.0)
# Requirement already satisfied: Flask-CORS<7 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (6.0.2)
# Requirement already satisfied: Flask<4 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.18.3)
# Requirement already satisfied: cryptography<47,>=43.0.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (46.0.4)
# Requirement already satisfied: docker<8,>=4.0.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (7.1.0)
# Requirement already satisfied: gunicorn<24 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.4 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (2.6.0)
# Requirement already satisfied: matplotlib<4 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.10.8)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.8.0)
# Requirement already satisfied: skops<1 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.13.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (2.0.46)
# Requirement already satisfied: cachetools<7,>=5.0.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (8.3.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.83.0)
# Requirement already satisfied: fastapi<1 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.128.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.1.46)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.39.1)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.2.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.5.5)
# Requirement already satisfied: uvicorn<1 in ./.venv/venv/lib/python3.12/site-packages (from mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.40.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in ./.venv/venv/lib/python3.12/site-packages (from omegaconf>=2.1.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (4.9.3)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/venv/lib/python3.12/site-packages (from pandas>=1.0.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2025.3)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/venv/lib/python3.12/site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (5.0.0)
# Requirement already satisfied: invoke>=2.0 in ./.venv/venv/lib/python3.12/site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2.2.1)
# Requirement already satisfied: pynacl>=1.5 in ./.venv/venv/lib/python3.12/site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (1.6.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2026.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/venv/lib/python3.12/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/venv/lib/python3.12/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2.19.2)
# Requirement already satisfied: filelock in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (3.20.3)
# Requirement already satisfied: setuptools in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2026.1.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in ./.venv/venv/lib/python3.12/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in ./.venv/venv/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (1.3.3)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in ./.venv/venv/lib/python3.12/site-packages (from deepdiff->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (5.5.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in ./.venv/venv/lib/python3.12/site-packages (from onnx->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.5.4)
# Requirement already satisfied: coloredlogs in ./.venv/venv/lib/python3.12/site-packages (from onnxruntime->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (15.0.1)
# Requirement already satisfied: flatbuffers in ./.venv/venv/lib/python3.12/site-packages (from onnxruntime->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (25.12.19)
# Requirement already satisfied: iniconfig>=1.0.1 in ./.venv/venv/lib/python3.12/site-packages (from pytest->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./.venv/venv/lib/python3.12/site-packages (from pytest->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.6.0)
# Requirement already satisfied: json5>=0.9.22 in ./.venv/venv/lib/python3.12/site-packages (from sagemaker_schema_inference_artifacts->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.13.0)
# Requirement already satisfied: python-rapidjson>=0.9.1 in ./.venv/venv/lib/python3.12/site-packages (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.1 in ./.venv/venv/lib/python3.12/site-packages (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.13.3)
# Requirement already satisfied: geventhttpclient>=2.3.3 in ./.venv/venv/lib/python3.12/site-packages (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (2.3.7)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.22.0)
# Requirement already satisfied: Mako in ./.venv/venv/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in ./.venv/venv/lib/python3.12/site-packages (from cryptography<47,>=43.0.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (2.0.0)
# Requirement already satisfied: blinker>=1.9.0 in ./.venv/venv/lib/python3.12/site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in ./.venv/venv/lib/python3.12/site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (2.2.0)
# Requirement already satisfied: werkzeug>=3.1.0 in ./.venv/venv/lib/python3.12/site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.1.5)
# Requirement already satisfied: gevent in ./.venv/venv/lib/python3.12/site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (25.9.1)
# Requirement already satisfied: brotli in ./.venv/venv/lib/python3.12/site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/venv/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/venv/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/venv/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/venv/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in ./.venv/venv/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/venv/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.3.2)
# Requirement already satisfied: joblib>=1.3.0 in ./.venv/venv/lib/python3.12/site-packages (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in ./.venv/venv/lib/python3.12/site-packages (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in ./.venv/venv/lib/python3.12/site-packages (from skops<1->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.17.0)
# Requirement already satisfied: greenlet>=1 in ./.venv/venv/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.9.0->sagemaker-core<3.0.0,>=2.4.0->sagemaker==3.4.0) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in ./.venv/venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (10.0)
# Requirement already satisfied: pycparser in ./.venv/venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (3.0)
# Requirement already satisfied: google-auth~=2.0 in ./.venv/venv/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (2.48.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in ./.venv/venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.venv/venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/venv/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (4.0.12)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in ./.venv/venv/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.60b1)
# Requirement already satisfied: wcwidth in ./.venv/venv/lib/python3.12/site-packages (from prettytable>=3.9->skops<1->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.5.3)
# Requirement already satisfied: h11>=0.8 in ./.venv/venv/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.16.0)
# Requirement already satisfied: zope.event in ./.venv/venv/lib/python3.12/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (6.1)
# Requirement already satisfied: zope.interface in ./.venv/venv/lib/python3.12/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (8.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in ./.venv/venv/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (4.12.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.venv/venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow->sagemaker-serve<2.0.0,>=1.4.0->sagemaker==3.4.0) (0.6.2)
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml

# %% [markdown]
# ## 3. AWS Setup
#
# Configure AWS settings and get the execution role for SageMaker AI.

# %%
# Create IAM Client
iam = boto3.client('iam')
sts = boto3.client('sts')

# Get Account id
account_id = sts.get_caller_identity()['Account']
print(f"Account ID: {account_id}")

# Role name
role_name = 'ESFTTrainingRole'

# Trust Policy
trust_policy = {
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Principal": {
                "Service": [
                    "sagemaker.amazonaws.com",
                    "ec2.amazonaws.com"
                ]
            },
            "Action": "sts:AssumeRole"
        }
    ]
}

# 2. Create Role
try:
    response = iam.create_role(
        RoleName=role_name,
        AssumeRolePolicyDocument=json.dumps(trust_policy),
        Description='Role for ECR, S3, SageMaker Full Access',
        MaxSessionDuration=3600  # 1시간
    )
    print(f"Role Created: {response['Role']['Arn']}")
except iam.exceptions.EntityAlreadyExistsException:
    print(f"Role '{role_name}' already exists.")

# 3. Connect AWS Managed Policy
managed_policies = [
    'arn:aws:iam::aws:policy/AmazonEC2ContainerRegistryFullAccess',  # ECR
    'arn:aws:iam::aws:policy/AmazonS3FullAccess',                     # S3
    'arn:aws:iam::aws:policy/AmazonSageMakerFullAccess'               # SageMaker
]

for policy_arn in managed_policies:
    iam.attach_role_policy(
        RoleName=role_name,
        PolicyArn=policy_arn
    )
    print(f"ㄴ Policy Connected: {policy_arn.split('/')[-1]}")

role = f"arn:aws:iam::{account_id}:role/{role_name}"

# AWS setting Finalize
region = REGION or boto3.Session().region_name or 'us-east-2'
s3_bucket = f"sagemaker-{region}-{account_id}"  # It will be created automatically

print(f"\n" + "=" * 20)
print(f"Account ID: {account_id}")
print(f"Region: {region}")
print(f"S3 Bucket: {s3_bucket}")
print(f"Role: {role}")
# Out:
# Account ID: 798050803670
# Role 'ESFTTrainingRole' already exists.
# ㄴ Policy Connected: AmazonEC2ContainerRegistryFullAccess
# ㄴ Policy Connected: AmazonS3FullAccess
# ㄴ Policy Connected: AmazonSageMakerFullAccess
#
# ====================
# Account ID: 798050803670
# Region: us-east-1
# S3 Bucket: sagemaker-us-east-1-798050803670
# Role: arn:aws:iam::798050803670:role/ESFTTrainingRole

# %% [markdown]
# ## 4. Upload Dataset to S3
#
# Upload the Cherokee-English translation dataset to S3 bucket. This dataset contains parallel text pairs for low-resource language translation.
# Note that SageMaker Training Job requires datasets to be in S3 format and it will be automatically downloaded under `/opt/ml/input/data` directory.

# %%
# Upload Cherokee-English translation dataset to S3
print(f"Uploading Cherokee-English translation dataset: \n Train: {TRAIN_DATASET}\n Eval: {EVAL_DATASET}")
s3_upload(TRAIN_DATASET, f"s3://{s3_bucket}/input/data/train/")
s3_upload(EVAL_DATASET, f"s3://{s3_bucket}/input/data/eval/")

# Set the dataset path for SageMaker container
train_dataset = f"/opt/ml/input/data/train/{os.path.basename(TRAIN_DATASET)}"
eval_dataset = f"/opt/ml/input/data/eval/{os.path.basename(EVAL_DATASET)}"
# Out:
# Uploading Cherokee-English translation dataset:
#  Train: datasets/train/translation.jsonl
#  Eval: datasets/eval/translation.jsonl
# datasets/train/translation.jsonl is uploaded at s3://sagemaker-us-east-1-798050803670/input/data/train/translation.jsonl
# datasets/eval/translation.jsonl is uploaded at s3://sagemaker-us-east-1-798050803670/input/data/eval/translation.jsonl

# %% [markdown]
# ## 5. Configure Hyperparameters
#
# Set up the ESFT-specific hyperparameters. These parameters control expert selection and specialized fine-tuning behavior.
#
# Expert scoring
# - methodology and threshold settings are critical for determining which experts to train
# - `n_sample_tokens` is recommended over $2^{17}$ tokens
# - `score_function` can be choosen in ["token", "gate"]
# - `score_threshold` is recommended under 0.5. Higher threshold can cause inefficent training
#
# ESFT Training
# - `train_shared_experts` and `train_non_expert_modules` are set to `false` for the most efficient training. If you want to focus on downstream task performance, set them to `true`

# %%
# ESFT-specific hyperparameters for Cherokee-English translation
hyperparameters = {
    "model": MODEL,
    "score_function": SCORE_FUNCTION,  # Expert scoring method
    "score_threshold": str(SCORE_THRESHOLD),  # Threshold for expert selection
    "world_size": str(WORLD_SIZE),
    "gpus_per_process": str(NUM_GPU),
    "train_dataset": train_dataset,
    "eval_dataset": eval_dataset,
    # Expert scoring configuration
    "n_sample_tokens": str(SCORE_TOKENS),  # Tokens used for expert scoring
    "score_function": "token",
    "score_threshold": "0.2",
    # ESFT-specific training configuration
    "train_shared_experts": "false",  # Only train selected experts
    "train_non_expert_modules": "false",  # Focus on expert modules only
    "expert_config_dir": "",
    # Standard training parameters optimized for low-resource translation
    "train_epochs": "1",
    "micro_batch_size": "1",
    "global_batch_size": "256",
    "learning_rate": "7e-6",
    "warmup_ratio": "0.1",
    "weight_decay": "0.1",
    "min_learning_rate": "0.0",
    "max_length": "16384",
    "lr_decay_style": "cosine",
    "save_interval": "100",
    "use_wandb": "false",
    "expert_parallel": str(NUM_GPU),
    "pipeline_parallel": "1",
}

print("ESFT Hyperparameters for Cherokee-English Translation:")
print("\nCore ESFT Parameters:")
print(f"  model: {hyperparameters['model']}")
print(f"  score_function: {hyperparameters['score_function']}")
print(f"  score_threshold: {hyperparameters['score_threshold']}")
print(f"  n_sample_tokens: {hyperparameters['n_sample_tokens']}")
print("\nDataset Configuration:")
print(f"  train_dataset: {hyperparameters['train_dataset']}")
print(f"  eval_dataset: {hyperparameters['eval_dataset']}")
print("\nTraining Configuration:")
print(f"  train_epochs: {hyperparameters['train_epochs']}")
print(f"  learning_rate: {hyperparameters['learning_rate']}")
print(f"  global_batch_size: {hyperparameters['global_batch_size']}")
# Out:
# ESFT Hyperparameters for Cherokee-English Translation:
#
# Core ESFT Parameters:
#   model: Qwen/Qwen3-30B-A3B-Instruct-2507
#   score_function: token
#   score_threshold: 0.2
#   n_sample_tokens: 16384
#
# Dataset Configuration:
#   train_dataset: /opt/ml/input/data/train/translation.jsonl
#   eval_dataset: /opt/ml/input/data/eval/translation.jsonl
#
# Training Configuration:
#   train_epochs: 1
#   learning_rate: 7e-6
#   global_batch_size: 256

# %% [markdown]
# ## 6. Configure SageMaker Training Components
#
# Set up the SageMaker training configuration.

# %%
# SageMaker configuration
source_code = SourceCode(
    command="python /opt/ml/code/sagemaker_entrypoint.py",  # already uploaded in the docker img
)

compute = Compute(
    instance_count=1,
    instance_type=INSTANCE,
    volume_size_in_gb=STORAGE_VOLUME,
)

tb_config = TensorBoardOutputConfig(
    s3_output_path=f"s3://{s3_bucket}/output/tensorboard",
    local_path="/opt/ml/output/tensorboard"
)

input_data_config = [
    InputData(
        data_source=f"s3://{s3_bucket}/input/data/train/",
        channel_name="train",
    ),
    InputData(
        data_source=f"s3://{s3_bucket}/input/data/eval/",
        channel_name="eval",
    ),
]

stopping_condition = StoppingCondition(
    max_runtime_in_seconds = MAX_RUN_HOURS * 3600
)

print(f"Instance Type: {INSTANCE}")
print(f"Volume Size: 100 GB")
print(f"TensorBoard Output: s3://{s3_bucket}/output/tensorboard")
# Out:
# Instance Type: ml.p4d.24xlarge
# Volume Size: 100 GB
# TensorBoard Output: s3://sagemaker-us-east-1-798050803670/output/tensorboard

# %% [markdown]
# ## 7. Create and Configure ModelTrainer
#
# Initialize the SageMaker ModelTrainer with all configurations.

# %%
# Create ModelTrainer
model_trainer = ModelTrainer(
    training_image=SM_IMAGE_URI,
    source_code=source_code,
    compute=compute,
    hyperparameters=hyperparameters,
    role=role,
    base_job_name="esft",
    stopping_condition=stopping_condition,
    environment={
        "TOKENIZERS_PARALLELISM": "false",
    }
)

# Add TensorBoard configuration
model_trainer.with_tensorboard_output_config(tb_config)

print("ModelTrainer configured successfully!")
print(f"Base job name: esft")
print(f"Training image: {SM_IMAGE_URI}")
# Out:
# [02/09/26 09:47:01] INFO     SageMaker session not provided. Using default Session.                  ]8;id=539777;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/train/defaults.py\defaults.py]8;;\:]8;id=838616;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/train/defaults.py#61\61]8;;\
# [02/09/26 09:47:02] INFO     OutputDataConfig not provided. Using default:                          ]8;id=394427;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/train/defaults.py\defaults.py]8;;\:]8;id=753812;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/train/defaults.py#150\150]8;;\
#                              s3_output_path='s3://sagemaker-us-east-1-798050803670/esft'
#                              kms_key_id=None compression_type='GZIP'
#                              remove_job_name_from_s3_output_path=<sagemaker.core.utils.utils.Unassi
#                              gned object at 0x75e90cf7ca40>
#                              disable_model_upload=<sagemaker.core.utils.utils.Unassigned object at
#                              0x75e90cf7ca40> channels=<sagemaker.core.utils.utils.Unassigned object
#                              at 0x75e90cf7ca40>
#                     INFO     Training image URI:                                               ]8;id=458515;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/train/model_trainer.py\model_trainer.py]8;;\:]8;id=198539;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/train/model_trainer.py#548\548]8;;\
#                              798050803670.dkr.ecr.us-east-1.amazonaws.com/esft-sagemaker-nvcr:
#                              0.0.1
# ModelTrainer configured successfully!
# Base job name: esft
# Training image: 798050803670.dkr.ecr.us-east-1.amazonaws.com/esft-sagemaker-nvcr:0.0.1

# %% [markdown]
# ## 8. Start Training Job
#
# Launch the SageMaker training job. If you got errors like below, please visit [AWS Service Quotas](https://console.aws.amazon.com/servicequotas/) to increase instance limits
#
# > ResourceLimitExceeded: An error occurred (ResourceLimitExceeded) when calling the CreateTrainingJob operation: The account-level service limit 'ml.p5.48xlarge for training job usage' is 0 Instances, with current utilization of 0. Instances and a request delta of 1 Instances. Please use AWS Service Quotas to request an increase for this quota. If AWS Service Quotas is not available, contact AWS support to request an increase for this quota.

# %%
# Job Info
print("="*50)
print("SageMaker Training Start")
print(f"Instance Type: {INSTANCE}")
print(f"Instance Count: 1")
print(f"Model: {MODEL}")
print(f"Train Dataset: {TRAIN_DATASET}")
print(f"Valid Dataset: {EVAL_DATASET}")
print(f"Output Location: {model_trainer.output_data_config}")
print("="*50)

# Start training
model_trainer.train(
    input_data_config=input_data_config,
    wait=False,   # Wait for the training job to complete
    logs=False    # Display the training container logs
)

print("="*50)
print("Training Job Submitted!")
print("="*50)
# Out:
# ==================================================
# SageMaker Training Start
# Instance Type: ml.p4d.24xlarge
# Instance Count: 1
# Model: Qwen/Qwen3-30B-A3B-Instruct-2507
# Train Dataset: datasets/train/translation.jsonl
# Valid Dataset: datasets/eval/translation.jsonl
# Output Location: s3_output_path='s3://sagemaker-us-east-1-798050803670/esft' kms_key_id=None compression_type='GZIP' remove_job_name_from_s3_output_path=<sagemaker.core.utils.utils.Unassigned object at 0x75e90cf7ca40> disable_model_upload=<sagemaker.core.utils.utils.Unassigned object at 0x75e90cf7ca40> channels=<sagemaker.core.utils.utils.Unassigned object at 0x75e90cf7ca40>
# ==================================================
#                     INFO     SageMaker Python SDK will collect telemetry to help us better  ]8;id=877078;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/core/telemetry/telemetry_logging.py\telemetry_logging.py]8;;\:]8;id=645326;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/core/telemetry/telemetry_logging.py#92\92]8;;\
#                              understand our user's needs, diagnose issues, and deliver
#                              additional features.
#                              To opt out of telemetry, please disable via TelemetryOptOut
#                              parameter in SDK defaults config. For more information, refer
#                              to
#                              https://sagemaker.readthedocs.io/en/stable/overview.html#confi
#                              guring-and-using-defaults-with-the-sagemaker-python-sdk.
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ubuntu/.config/sagemaker/config.yaml
#                     INFO     Creating training_job resource.                                     ]8;id=693800;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=789877;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/core/resources.py#35539\35539]8;;\
#                     WARNING  No region provided. Using default region.                                 ]8;id=237786;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/core/utils/utils.py\utils.py]8;;\:]8;id=73529;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/core/utils/utils.py#340\340]8;;\
#                     INFO     Runs on sagemaker prod, region:us-east-1                                  ]8;id=603255;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/core/utils/utils.py\utils.py]8;;\:]8;id=994547;file:///home/ubuntu/git_repos/ESFT-ms-swift/.venv/venv/lib/python3.12/site-packages/sagemaker/core/utils/utils.py#354\354]8;;\
# ==================================================
# Training Job Submitted!
# ==================================================

# %% [markdown]
# ## 9. Training Results
#
# Check the training job status and results. You can also find your SageMaker Training Job at AWS console [SageMaker Training Job Console](https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/jobs). The training log will be found at [AWS Cloud Watch](https://console.aws.amazon.com/cloudwatch/home?region=us-east-1#logsV2:log-groups/log-group/$252Faws$252Fsagemaker$252FTrainingJobs)

# %%
# Get training job information
client = boto3.client('sagemaker')
training_job = client.list_training_jobs(MaxResults=10, SortBy='CreationTime')['TrainingJobSummaries']

valid_status = ['InProgress','Completed','Failed']
training_job = [job for job in training_job if job['TrainingJobStatus'] in valid_status]

print("Training job details:")
print(f"Job Name: {training_job[0]['TrainingJobName']}")
print(f"Job Status: {training_job[0]['TrainingJobStatus']}")
print(f"SageMaker Training Job Console: https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/jobs/{training_job[0]['TrainingJobName']}")
# Out:
# Training job details:
# Job Name: esft-20260209094702
# Job Status: InProgress
# SageMaker Training Job Console: https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/jobs/esft-20260209094702

# %% [markdown]
# You can check computation status at the AWS console as below
# ![image](assets/GPU-utilization.png)

# %% [markdown]
# It is easy to check training curve by SageMaker Tensorboard application. When you run the code below, it will automatically redirect to the tensorboard page.
# Alternatively, you can download tensorboard file from s3 bucket to local and run it directly.

# %%
from sagemaker.core.interactive_apps import TensorBoardApp

app = TensorBoardApp(REGION)
print(
    app.get_app_url(
        training_job_name = training_job[0]['TrainingJobName'],
    )
)

# %% [markdown]
# ![image](assets/tensorboard.png)

# %% [markdown]
# ## 10. Download model
#
# Finally, we can download trained model and output results from s3 bucket.

# %%
training_job_details = client.describe_training_job(TrainingJobName=training_job['TrainingJobName'])
model_s3_path = training_job_details['ModelArtifacts']['S3ModelArtifacts']
output_s3_path = model_s3_path.replace("model.tar.gz", "output.tar.gz")
print(f"\nModel artifects: {model_s3_path}")
print(f"Output S3: {training_job_details['OutputDataConfig']['S3OutputPath']}")
print(f"Tensorboard S3: {training_job_details['TensorBoardOutputConfig']['S3OutputPath']}")

# %%
# Download model
s3 = boto3.client('s3')
s3.download_file(s3_bucket, output_s3_path.split(f"{s3_bucket}/")[-1], 'model.tar.gz')
